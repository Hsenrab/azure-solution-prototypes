# %% [markdown]
# # 02 – Configure
#
# This notebook uses the **Python SDK** to perform any post-deployment configuration needed before
# the scenario can run — for example: verifying deployment readiness, creating a search index,
# uploading data, or registering a model endpoint.
#
# > **If your demo has no configuration step, you can skip or delete this notebook.**
#
# **Pre-requisite:** `01_deploy_infra.ipynb` must have run and written `env/.env`.
#
# ---
#
# ## SDK guidance
#
# > **Use `azure-ai-inference` (new Azure AI Foundry SDK) for all model inference.**
# > This replaces the classic `openai.AzureOpenAI` pattern for new demos.
# > `ChatCompletionsClient` works with any model in the Foundry catalog, not just OpenAI models.
# >
# > For other services (AI Search, Blob Storage etc.) use the respective Azure SDK.
# > Label any `[PREVIEW]` API features clearly in notebook markdown.
#
# ---

# %% [markdown]
# ## Step 1 – Load environment variables

# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path="../env/.env")

# Read the values written by 01_deploy_infra.ipynb
# endpoint  = os.environ["AZURE_AI_ENDPOINT"]
# api_key   = os.environ["AZURE_AI_API_KEY"]
# deployment = os.environ.get("AZURE_AI_DEPLOYMENT", "chat")

print("Environment loaded")

# %% [markdown]
# ## Step 2 – Create SDK client(s)
#
# For model inference use `azure-ai-inference`. For other services use the respective Azure SDK.

# %%
# TODO: initialise the relevant SDK client(s), e.g.:
#
# from azure.ai.inference import ChatCompletionsClient
# from azure.core.credentials import AzureKeyCredential
#
# client = ChatCompletionsClient(
#     endpoint=endpoint,
#     credential=AzureKeyCredential(api_key),
# )
#
# For AI Search (RAG demos):
# from azure.search.documents.indexes import SearchIndexClient
# index_client = SearchIndexClient(
#     endpoint=os.environ["AZURE_SEARCH_ENDPOINT"],
#     credential=AzureKeyCredential(os.environ["AZURE_SEARCH_KEY"]),
# )

print("TODO: create SDK client(s)")

# %% [markdown]
# ## Step 3 – Configure
#
# Perform the configuration steps required for your demo. Add as many cells as needed.
# Label any `[PREVIEW]` features clearly in the markdown above each cell.

# %%
# TODO: configuration step 1
# e.g. verify deployment is Succeeded, create a search index, upload sample data
print("TODO: configuration step 1")

# %%
# TODO: configuration step 2 (add more cells as needed)
print("TODO: configuration step 2")

# %% [markdown]
# ## Step 4 – Verify configuration

# %%
# TODO: verify the configuration, e.g. list indexes, ping the model endpoint
print("TODO: verify configuration")

# %% [markdown]
# ---
#
# ## ✅ Configuration complete
#
# Move to **`03_test.ipynb`** to run the demo scenario.
