# %% [markdown]
# # 02 – Configure
#
# This notebook uses the **Python SDK** to perform any post-deployment configuration needed before the scenario can run — for example: creating a search index, uploading data, registering a model, or setting access policies.
#
# > **If your demo has no configuration step, you can skip or delete this notebook.**
#
# **Pre-requisite:** `01_deploy_infra.ipynb` must have run and written `env/.env`.
#
# ---

# %% [markdown]
# ## Step 1 – Load environment variables

# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path="../env/.env")

# Read the values written by 01_deploy_infra.ipynb
# some_endpoint = os.environ["SOME_ENDPOINT"]
# some_key      = os.environ["SOME_KEY"]

print("Environment loaded")

# %% [markdown]
# ## Step 2 – Create SDK client(s)
#
# Initialise Python SDK clients for the services that need configuring.

# %%
# TODO: initialise the relevant SDK client(s), e.g.:
#
# from azure.search.documents.indexes import SearchIndexClient
# from azure.core.credentials import AzureKeyCredential
#
# index_client = SearchIndexClient(
#     endpoint=os.environ["SEARCH_ENDPOINT"],
#     credential=AzureKeyCredential(os.environ["SEARCH_KEY"]),
# )

print("TODO: create SDK client(s)")

# %% [markdown]
# ## Step 3 – Configure
#
# Perform the configuration steps required for your demo. Add as many cells as needed — each meaningful action should be its own cell with a short markdown explanation above it.

# %%
# TODO: configuration step 1
# e.g. create a search index, upload sample data, register a model endpoint
print("TODO: configuration step 1")

# %%
# TODO: configuration step 2 (add more cells as needed)
print("TODO: configuration step 2")

# %% [markdown]
# ## Step 4 – Verify configuration
#
# A quick check to confirm the configuration was applied correctly before moving to testing.

# %%
# TODO: verify the configuration, e.g. list indexes, check blob exists, describe endpoint
print("TODO: verify configuration")

# %% [markdown]
# ---
#
# ## ✅ Configuration complete
#
# Move to **`03_test.ipynb`** to run the demo scenario.
